# %% [markdown]
# ### Task 2 - Probability

# %% [markdown]
# 1. What is probability? Give an example

# %% [markdown]
# Ans:-
# > Defination: probability measured the likelihood of event occuring.
#
# ***Example***
# ##### Chance of getting Heads when tossing a coin

# %% [markdown]
# 2. What is the formula of probability?

# %% [markdown]
# Ans:-
# >***P(E)=
# Total Outcomes/Favorable Outcomes***

# %% [markdown]
# 3. What are the different types of probability?

# %% [markdown]
# Ans:-
# 1. Classical Probability
# 2. Empirical probability
# 3. Subjective probability
# 4. Conditional probability

# %% [markdown]
# 4. What is the sample space for tossing two coins?

# %% [markdown]
# Ans:-
# > S = {HH,HT,TH,TT}

# %% [markdown]
# 5. Draw a random card from a pack of cards. What is the probability that the card drawn is a face card?

# %% [markdown]
# Ans:-
#
# ***Face Cards:*** J,Q,K
# * Total face cards = 12
# * Total Cards = 52
#
# > P = 12/52 =3/13

# %% [markdown]
# 6. What is the probability of getting a sum of 10 when two dice are thrown?

# %% [markdown]
# Ans:-
#
# ***Favorable Outcomes:***
#
# (4,6),(5,5),(6,4)-->3
#
# Total outcomes = 36
#
# ***P=3/36=1/12***

# %% [markdown]
# 7. In a bag, there are 6 blue balls and 8 yellow balls. One ball is selected randomly from the bag. Find the probability of getting a blue ball.

# %% [markdown]
# Ans:-
#
# ***Blue Ball Probability***
#
# Blue balls = 6
#
# Total balle = 14
#
# ***P=6/14=3/7***

# %% [markdown]
# 8. What is the Conditional Probability Formula?

# %% [markdown]
# Ans:-
#
# ***P(A/B)=P(A^B)/P(B)***
#
# > Probabilty of A occuring given that B has already occured
